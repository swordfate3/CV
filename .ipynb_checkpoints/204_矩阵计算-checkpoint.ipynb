# %% [markdown]
# # 1. 标量导数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 亚导数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. 求导

# %% [markdown]
# ## 3.1 梯度

# %% [markdown]
# ① y是向量，x是标量的话，求导为标量。
#
# ② y是向量，x是向量的话，求导为矩阵。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.2 标量对向量求导

# %% [markdown]
# ③ $x_{1}^{2}+2x_{2}^{2}$是一个椭圆，梯度是指向值变化最大的方向。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.3 向量对标量求导

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.4 向量对向量求导

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.5 扩展矩阵对矩阵求导

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![32AMVA3U`]_COFK1]6D2T8E.png](attachment:00b7305a-af2d-4148-8fa0-6db53504020d.png)
